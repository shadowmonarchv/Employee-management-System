# %% [markdown]
# # Pandas
# We will learn about the basics of Pandas, which is a powerful, open-source data analysis and manipulation library for Python built on top of the NumPy package. **Pandas** is derived from the term **panel data**.
#
# In this session, we will study Pandas data structures and understand how to study their attributes and access their member elements and values.
#
# To get started using `Pandas`, import it into your Python program as follows:

# %%
import pandas as pd

# %% [markdown]
# The two most important data structures in `Pandas` are the `Series` and the `DataFrame` classes. A series is essentially a single variable with multiple values recorded for different observations. Putting multiple series together across the same observations gives you a dataframe.

# %% [markdown]
# # Series
# The Pandas `Series` object is a 1D labeled array capable of holding data of any type.

# %% [markdown]
# ### Example
# Creating series from lists

# %%
empty_series = pd.Series()
# Out:
# C:\Users\askpr\AppData\Local\Temp\ipykernel_16320\1892664345.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty_series = pd.Series()

# %%
empty_series
# Out:
# Series([], dtype: float64)

# %%
empty_series = pd.Series(data = None, dtype = 'int')

# %%
empty_series
# Out:
# Series([], dtype: int32)

# %%
type(empty_series)
# Out:
# pandas.core.series.Series

# %%
print(empty_series)
# Out:
# Series([], dtype: int32)

# %%
prices = [649000, 391000, 5476000, 1786000, 1091000]
carnames = ['swift', 'santro', 'audi', 'elantra', 'bolero']

# %%
car_series = pd.Series(data = prices, index = carnames)
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# dtype: int64

# %%
type(car_series)
# Out:
# pandas.core.series.Series

# %%
car_series = pd.Series(prices)
car_series
# Out:
# 0     649000
# 1     391000
# 2    5476000
# 3    1786000
# 4    1091000
# dtype: int64

# %%
car_series = pd.Series(prices, carnames, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %% [markdown]
# The `name` attribute for the Pandas series is optional but helpful and makes the data organization neater and easier to handle.

# %% [markdown]
# ### Example
# Creating series from dictionaries

# %%
entries = {'swift': 649000,
           'santro': 391000,
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %% [markdown]
# Notice how the index and the values are meaningfully interpreted from the keys and the values of the dictionary.

# %%
entries = {'swift': 649000,
           'santro': '391000',
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: object

# %%
type(car_series['swift'])
# Out:
# int

# %%
type(car_series['santro'])
# Out:
# str

# %% [markdown]
# Notice how the series shows an `object` data type but the elements within the series have their own data types, namely, `int` and `str`, wherever applicable.

# %% [markdown]
# We will study more about indexing and accessing later in the session.

# %% [markdown]
# ### Example
# Looking at some series attributes

# %% [markdown]
# Series have attributes similar to arrays, and a few more, that make the life of a data analyst easier.

# %%
entries = {'swift': 649000,
           'santro': 391000,
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series.name
# Out:
# 'price'

# %%
car_series.index
# Out:
# Index(['swift', 'santro', 'audi', 'elantra', 'bolero'], dtype='object')

# %%
car_series.values
# Out:
# array([ 649000,  391000, 5476000, 1786000, 1091000], dtype=int64)

# %%
car_series.dtype
# Out:
# dtype('int64')

# %%
car_series.shape
# Out:
# (5,)

# %%
car_series.ndim
# Out:
# 1

# %%
car_series.size
# Out:
# 5

# %%
len(car_series)
# Out:
# 5

# %%
car_series.empty
# Out:
# False

# %% [markdown]
# # Accessing data from series
#
# In this section, we will study various methods to access data from series.

# %% [markdown]
# ### Example
# Accessing data from series using logical conditions

# %%
entries = {'swift': 649000,
           'santro': 391000,
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series > 1000000
# Out:
# swift      False
# santro     False
# audi        True
# elantra     True
# bolero      True
# Name: price, dtype: bool

# %%
car_series[car_series>1000000]
# Out:
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series[car_series > 1000000]
# Out:
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series[car_series > 1000000].index
# Out:
# Index(['audi', 'elantra', 'bolero'], dtype='object')

# %%
car_series[car_series > 1000000].values
# Out:
# array([5476000, 1786000, 1091000], dtype=int64)

# %%
car_series[car_series > 1000000].index[0]
# Out:
# 'audi'

# %%
car_series[car_series > 1000000].index[1]
# Out:
# 'elantra'

# %%
car_series[car_series > 1000000].index[2]
# Out:
# 'bolero'

# %%
car_series[car_series > 1000000].values[0]
# Out:
# 5476000

# %%
car_series[car_series > 1000000].values[1]
# Out:
# 1786000

# %%
car_series[car_series > 1000000].values[2]
# Out:
# 1091000

# %%
(car_series > 1000000) & (car_series < 2000000)
# Out:
# swift      False
# santro     False
# audi       False
# elantra     True
# bolero      True
# Name: price, dtype: bool

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)]
# Out:
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %% [markdown]
# Pandas objects such as series and dataframes strictly follow indexing. This is critical in data science to keep track of data entries and associated values.

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)].index
# Out:
# Index(['elantra', 'bolero'], dtype='object')

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)].values
# Out:
# array([1786000, 1091000], dtype=int64)

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)].index[0]
# Out:
# 'elantra'

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)].index[1]
# Out:
# 'bolero'

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)].values[0]
# Out:
# 1786000

# %%
car_series[(car_series > 1000000) & (car_series < 2000000)].values[1]
# Out:
# 1091000

# %% [markdown]
# ### Quiz
# Consider the series shown below:
# ```
# cust_names = ['Chad', 'Farheen', 'Himadri', 'Monisha']
# cust_bill = [256.78, 434.53, 109.25, 529.42]
# cust_info = pd.Series(cust_bill, cust_names)
# ```
# Write code to print the names of the customers who have spent more than 300 rupees.

# %%
cust_names = ['Chad', 'Farheen', 'Himadri', 'Monisha']
cust_bill = [256.78, 434.53, 109.25, 529.42]
cust_info = pd.Series(cust_bill, cust_names)
print(list(cust_info[cust_info > 300].index))
# Out:
# ['Farheen', 'Monisha']

# %% [markdown]
# ### Example
# Accessing data from series using the names of the entries

# %%
entries = {'swift': 649000,
           'santro': 391000,
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series['swift']
# Out:
# 649000

# %%
car_series[['swift']]
# Out:
# swift    649000
# Name: price, dtype: int64

# %%
car_series[['swift', 'audi']]
# Out:
# swift     649000
# audi     5476000
# Name: price, dtype: int64

# %%
car_series[['swift', 'audi', 'bolero']]
# Out:
# swift      649000
# audi      5476000
# bolero    1091000
# Name: price, dtype: int64

# %%
car_series[['bolero', 'swift', 'audi']]
# Out:
# bolero    1091000
# swift      649000
# audi      5476000
# Name: price, dtype: int64

# %% [markdown]
# ### Example
# Accessing data from series using the `.loc[]` method

# %%
entries = {'swift': 649000,
           'santro': 391000,
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series.loc['swift']
# Out:
# 649000

# %%
car_series.loc[['swift']]
# Out:
# swift    649000
# Name: price, dtype: int64

# %%
car_series.loc[['swift', 'audi']]
# Out:
# swift     649000
# audi     5476000
# Name: price, dtype: int64

# %%
car_series.loc['swift':'elantra']
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# Name: price, dtype: int64

# %% [markdown]
# Note that this is similar to NumPy array slicing, but the `.loc[]` method is inclusive of the stop value as well.

# %%
car_series.loc['santro':'audi']
# Out:
# santro     391000
# audi      5476000
# Name: price, dtype: int64

# %%
car_series.loc[:'elantra']
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# Name: price, dtype: int64

# %% [markdown]
# ### Example
# Accessing data from series using the `.iloc[]` method

# %%
entries = {'swift': 649000,
           'santro': 391000,
           'audi': 5476000,
           'elantra': 1786000,
           'bolero': 1091000}
car_series = pd.Series(data = entries, name = 'price')
car_series
# Out:
# swift       649000
# santro      391000
# audi       5476000
# elantra    1786000
# bolero     1091000
# Name: price, dtype: int64

# %%
car_series.iloc[0]
# Out:
# 649000

# %%
car_series.iloc[3]
# Out:
# 1786000

# %%
car_series.iloc[[3]]
# Out:
# elantra    1786000
# Name: price, dtype: int64

# %%
car_series.iloc[[0, 2, 4]]
# Out:
# swift      649000
# audi      5476000
# bolero    1091000
# Name: price, dtype: int64

# %%
car_series.iloc[0:2]
# Out:
# swift     649000
# santro    391000
# Name: price, dtype: int64

# %% [markdown]
# Note that the `.iloc[]` method is not inclusive of the stop element like the `.loc[]` method. The `.iloc[]` method is very similar to NumPy array indexing and slicing.

# %%
car_series.iloc[-1]
# Out:
# 1091000

# %%
car_series.iloc[[-1]]
# Out:
# bolero    1091000
# Name: price, dtype: int64

# %%
car_series.iloc[1:5:2]
# Out:
# santro      391000
# elantra    1786000
# Name: price, dtype: int64

# %%
car_series.iloc[::-1]
# Out:
# bolero     1091000
# elantra    1786000
# audi       5476000
# santro      391000
# swift       649000
# Name: price, dtype: int64

# %% [markdown]
# In this section, we familiarized ourselves with the series object from the Pandas library. Note that the most common data structure that is used in data science from the Pandas library is the dataframe object, which is essentially a table of series with a common index. In the next section, we will study dataframes in detail. Learners are encouraged to explore more about series on their own.

# %% [markdown]
# ### Quiz
# Consider the series shown below:
# ```
# cust_names = ['Chad', 'Farheen', 'Himadri', 'Monisha']
# cust_bill = [256.78, 434.53, 109.25, 529.42]
# cust_info = pd.Series(cust_bill, cust_names)
# ```
# Use the different methods you have studied to extract the bill amounts for Chad and Monisha.

# %%
cust_names = ['Chad', 'Farheen', 'Himadri', 'Monisha']
cust_bill = [256.78, 434.53, 109.25, 529.42]
cust_info = pd.Series(cust_bill, cust_names)

# %%
cust_info[['Chad', 'Monisha']]
# Out:
# Chad       256.78
# Monisha    529.42
# dtype: float64

# %%
cust_info.loc[['Chad', 'Monisha']]
# Out:
# Chad       256.78
# Monisha    529.42
# dtype: float64

# %%
cust_info.iloc[[0, 3]]
# Out:
# Chad       256.78
# Monisha    529.42
# dtype: float64

# %% [markdown]
# # Dataframes
# A Dataframe is a 2D table made up of multiple series. We will study an introduction to dataframes in this session.

# %% [markdown]
# ### Example
# Creating dataframes

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.empty
# Out:
# True

# %% [markdown]
# While dataframes can be created using indexed data structures such as lists, we will study the dictionary method in this section. You may explore other ways of creating dataframes on your own.

# %%
cust_data = {'CustomerID' : ['001', '002', '003', '004'],
             'Name': ['Alice', 'Bharadwaj', 'Chiranjeev', 'Dawood'],
             'Email': ['a@example.com', 'b@example.com', 'c@example.com', 'd@example.com'],
             'Phone':  [1234567891, 8090809080, 4145145412, 1989898122],
             'TotalPurchases':  [20, 15, 25, 10]}
df = pd.DataFrame(cust_data)

# %% [markdown]
# Note that each feature of the dataframe is a list of values. The dataframe itself is a structured list of these features.

# %%
df
# Out:
#   CustomerID        Name          Email       Phone  TotalPurchases
# 0        001       Alice  a@example.com  1234567891              20
# 1        002   Bharadwaj  b@example.com  8090809080              15
# 2        003  Chiranjeev  c@example.com  4145145412              25
# 3        004      Dawood  d@example.com  1989898122              10

# %% [markdown]
# Note how the column names for the dataframe are inferred from the keys of the dictionary.

# %%
cust_data = {'CustomerID' : ['001', '002', '003', '004'],
            #  'Name': ['Alice', 'Bharadwaj', 'Chiranjeev', 'Dawood'],
             'Email': ['a@example.com', 'b@example.com', 'c@example.com', 'd@example.com'],
             'Phone':  [1234567891, 8090809080, 4145145412, 1989898122],
             'TotalPurchases':  [20, 15, 25, 10]}
cust_names = ['Alice', 'Bharadwaj', 'Chiranjeev', 'Dawood']
df = pd.DataFrame(data = cust_data, index = cust_names)

# %%
df
# Out:
#            CustomerID          Email       Phone  TotalPurchases
# Alice             001  a@example.com  1234567891              20
# Bharadwaj         002  b@example.com  8090809080              15
# Chiranjeev        003  c@example.com  4145145412              25
# Dawood            004  d@example.com  1989898122              10

# %%
cust_data = {'CustomerID' : ['001', '002', '003', '004'],
             'Email': ['a@example.com', 'b@example.com', 'c@example.com', 'd@example.com'],
             'Phone':  [1234567891, 8090809080, 4145145412, 1989898122],
             'TotalPurchases':  [20, 15, 25, 10]}
cust_names = ['Alice', 'Bharadwaj', 'Chiranjeev', 'Dawood']
df = pd.DataFrame(cust_data, cust_names)

# %%
df
# Out:
#            CustomerID          Email       Phone  TotalPurchases
# Alice             001  a@example.com  1234567891              20
# Bharadwaj         002  b@example.com  8090809080              15
# Chiranjeev        003  c@example.com  4145145412              25
# Dawood            004  d@example.com  1989898122              10

# %% [markdown]
# Keep in mind the order of the parameters when calling methods without specifying parameter names.

# %% [markdown]
# While you may only work on reading and analyzing data initially, learning to create and manipulate dataframes on the go becomes an integral part of data science as you move ahead in your learning journey.

# %% [markdown]
# ### Example
# Reading data into dataframes

# %% [markdown]
# While tabular data can be loaded into the Python environment from various source files, we will study how to read CSV files in this session.

# %%
import pandas as pd

# %%
df_cars = pd.read_csv('cars_dataset.csv') # without file path

# %%
df_cars = pd.read_csv('C:\\Users\\askpr\\Week 7 Pandas\\SME Session 1 - Introduction to Pandas\\cars_dataset.csv') 
# with file path , replace your system path with mine

# %%
df_cars.tail()
# Out:
#      car_ID  symboling       carname doornumber carbody enginelocation  \
# 142     197         -2   volvo 244dl       four   sedan          front
# 143     198         -1     volvo 245       four   wagon          front
# 144     199         -2   volvo 264gl       four   sedan          front
# 145     200         -1  volvo diesel       four   wagon          front
# 146     204         -1     volvo 246       four   sedan          front
#
#      wheelbase  carlength  carwidth  carheight  ...  cylindernumber  \
# 142      104.3      188.8      67.2       56.2  ...            four
# 143      104.3      188.8      67.2       57.5  ...            four
# 144      104.3      188.8      67.2       56.2  ...            four
# 145      104.3      188.8      67.2       57.5  ...            four
# 146      109.1      188.8      68.9       55.5  ...             six
#
#     enginesize  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 142        141       3.78    3.15               9.5         114     5400
# 143        141       3.78    3.15               9.5         114     5400
# 144        130       3.62    3.15               7.5         162     5100
# 145        130       3.62    3.15               7.5         162     5100
# 146        145       3.01    3.40              23.0         106     4800
#
#      citympg  highwaympg    price
# 142       24          28  15985.0
# 143       24          28  16515.0
# 144       17          22  18420.0
# 145       17          22  18950.0
# 146       26          27  22470.0
#
# [5 rows x 21 columns]

# %% [markdown]
# You can see the number of rows and columns in the dataset here. You can also look at some of the feature/column names and the entries.

# %%
df_cars.head() # to display top 5 records
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0

# %%
df_cars.head(2)
# Out:
#    car_ID  symboling              carname doornumber      carbody  \
# 0       1          3   alfa-romero giulia        two  convertible
# 1       2          3  alfa-romero stelvio        two  convertible
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# 0          front       88.6      168.8      64.1       48.8  ...
# 1          front       88.6      168.8      64.1       48.8  ...
#
#    cylindernumber enginesize  boreratio  stroke  compressionratio  horsepower  \
# 0            four        130       3.47    2.68               9.0         111
# 1            four        130       3.47    2.68               9.0         111
#
#    peakrpm  citympg  highwaympg    price
# 0     5000       21          27  13495.0
# 1     5000       21          27  16500.0
#
# [2 rows x 21 columns]

# %% [markdown]
# The `.head()` method is useful to quickly understand a dataframe's structure.

# %% [markdown]
# Whether to use the default integer index or to use unique identifiers such as car names or car models as the index depends on the data analysis methodology.

# %%
df_cars = pd.read_csv('cars_dataset.csv', index_col = 'carname') # make one column (carname) as index
df_cars
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
# ...                          ...        ...        ...          ...
# volvo 244dl                  197         -2       four        sedan
# volvo 245                    198         -1       four        wagon
# volvo 264gl                  199         -2       four        sedan
# volvo diesel                 200         -1       four        wagon
# volvo 246                    204         -1       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [147 rows x 20 columns]

# %% [markdown]
# ### Example
# Studying dataframes

# %%
df_cars
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
# ...                          ...        ...        ...          ...
# volvo 244dl                  197         -2       four        sedan
# volvo 245                    198         -1       four        wagon
# volvo 264gl                  199         -2       four        sedan
# volvo diesel                 200         -1       four        wagon
# volvo 246                    204         -1       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [147 rows x 20 columns]

# %%
df_cars.head()
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0

# %%
df_cars.head(n = 3)
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0

# %%
df_cars.head(2)
# Out:
#                      car_ID  symboling doornumber      carbody enginelocation  \
# carname
# alfa-romero giulia        1          3        two  convertible          front
# alfa-romero stelvio       2          3        two  convertible          front
#
#                      wheelbase  carlength  carwidth  carheight  curbweight  \
# carname
# alfa-romero giulia        88.6      168.8      64.1       48.8        2548
# alfa-romero stelvio       88.6      168.8      64.1       48.8        2548
#
#                     cylindernumber  enginesize  boreratio  stroke  \
# carname
# alfa-romero giulia            four         130       3.47    2.68
# alfa-romero stelvio           four         130       3.47    2.68
#
#                      compressionratio  horsepower  peakrpm  citympg  \
# carname
# alfa-romero giulia                9.0         111     5000       21
# alfa-romero stelvio               9.0         111     5000       21
#
#                      highwaympg    price
# carname
# alfa-romero giulia           27  13495.0
# alfa-romero stelvio          27  16500.0

# %%
df_cars.tail()
# Out:
#               car_ID  symboling doornumber carbody enginelocation  wheelbase  \
# carname
# volvo 244dl      197         -2       four   sedan          front      104.3
# volvo 245        198         -1       four   wagon          front      104.3
# volvo 264gl      199         -2       four   sedan          front      104.3
# volvo diesel     200         -1       four   wagon          front      104.3
# volvo 246        204         -1       four   sedan          front      109.1
#
#               carlength  carwidth  carheight  curbweight cylindernumber  \
# carname
# volvo 244dl       188.8      67.2       56.2        2935           four
# volvo 245         188.8      67.2       57.5        3042           four
# volvo 264gl       188.8      67.2       56.2        3045           four
# volvo diesel      188.8      67.2       57.5        3157           four
# volvo 246         188.8      68.9       55.5        3217            six
#
#               enginesize  boreratio  stroke  compressionratio  horsepower  \
# carname
# volvo 244dl          141       3.78    3.15               9.5         114
# volvo 245            141       3.78    3.15               9.5         114
# volvo 264gl          130       3.62    3.15               7.5         162
# volvo diesel         130       3.62    3.15               7.5         162
# volvo 246            145       3.01    3.40              23.0         106
#
#               peakrpm  citympg  highwaympg    price
# carname
# volvo 244dl      5400       24          28  15985.0
# volvo 245        5400       24          28  16515.0
# volvo 264gl      5100       17          22  18420.0
# volvo diesel     5100       17          22  18950.0
# volvo 246        4800       26          27  22470.0

# %%
df_cars.tail(2)
# Out:
#               car_ID  symboling doornumber carbody enginelocation  wheelbase  \
# carname
# volvo diesel     200         -1       four   wagon          front      104.3
# volvo 246        204         -1       four   sedan          front      109.1
#
#               carlength  carwidth  carheight  curbweight cylindernumber  \
# carname
# volvo diesel      188.8      67.2       57.5        3157           four
# volvo 246         188.8      68.9       55.5        3217            six
#
#               enginesize  boreratio  stroke  compressionratio  horsepower  \
# carname
# volvo diesel         130       3.62    3.15               7.5         162
# volvo 246            145       3.01    3.40              23.0         106
#
#               peakrpm  citympg  highwaympg    price
# carname
# volvo diesel     5100       17          22  18950.0
# volvo 246        4800       26          27  22470.0

# %%
df_cars.axes
# Out:
# [Index(['alfa-romero giulia', 'alfa-romero stelvio', 'alfa-romero Quadrifoglio',
#         'audi 100 ls', 'audi 100ls', 'audi fox', 'audi 5000', 'audi 4000',
#         'audi 5000s (diesel)', 'bmw 320i',
#         ...
#         'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#         'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#         'volvo 264gl', 'volvo diesel', 'volvo 246'],
#        dtype='object', name='carname', length=147),
#  Index(['car_ID', 'symboling', 'doornumber', 'carbody', 'enginelocation',
#         'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#         'cylindernumber', 'enginesize', 'boreratio', 'stroke',
#         'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#         'price'],
#        dtype='object')]

# %%
df_cars.index
# Out:
# Index(['alfa-romero giulia', 'alfa-romero stelvio', 'alfa-romero Quadrifoglio',
#        'audi 100 ls', 'audi 100ls', 'audi fox', 'audi 5000', 'audi 4000',
#        'audi 5000s (diesel)', 'bmw 320i',
#        ...
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'],
#       dtype='object', name='carname', length=147)

# %%
df_cars.columns # display list of columns
# Out:
# Index(['car_ID', 'symboling', 'doornumber', 'carbody', 'enginelocation',
#        'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'cylindernumber', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_cars.shape # size of data frame as 147 row and 20 columns
# Out:
# (147, 20)

# %%
df_cars.size
# Out:
# 2940

# %%
df_cars.head()
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0

# %%
df_cars.dtypes
# Out:
# car_ID                int64
# symboling             int64
# doornumber           object
# carbody              object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# cylindernumber       object
# enginesize            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df_cars.info() # memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, alfa-romero giulia to volvo 246
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            147 non-null    int64
#  1   symboling         147 non-null    int64
#  2   doornumber        147 non-null    object
#  3   carbody           147 non-null    object
#  4   enginelocation    147 non-null    object
#  5   wheelbase         147 non-null    float64
#  6   carlength         147 non-null    float64
#  7   carwidth          147 non-null    float64
#  8   carheight         147 non-null    float64
#  9   curbweight        147 non-null    int64
#  10  cylindernumber    147 non-null    object
#  11  enginesize        147 non-null    int64
#  12  boreratio         147 non-null    float64
#  13  stroke            147 non-null    float64
#  14  compressionratio  147 non-null    float64
#  15  horsepower        147 non-null    int64
#  16  peakrpm           147 non-null    int64
#  17  citympg           147 non-null    int64
#  18  highwaympg        147 non-null    int64
#  19  price             147 non-null    float64
# dtypes: float64(8), int64(8), object(4)
# memory usage: 24.1+ KB

# %% [markdown]
# Generally, the `shape`, `columns`, `index` and `info` commands are sufficient to study some important properties of dataframes.

# %%
df_cars.keys()
# Out:
# Index(['car_ID', 'symboling', 'doornumber', 'carbody', 'enginelocation',
#        'wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'cylindernumber', 'enginesize', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df_cars.values
# Out:
# array([[1, 3, 'two', ..., 21, 27, 13495.0],
#        [2, 3, 'two', ..., 21, 27, 16500.0],
#        [3, 1, 'two', ..., 19, 26, 16500.0],
#        ...,
#        [199, -2, 'four', ..., 17, 22, 18420.0],
#        [200, -1, 'four', ..., 17, 22, 18950.0],
#        [204, -1, 'four', ..., 26, 27, 22470.0]], dtype=object)

# %%
df_cars.transpose()
# Out:
# carname          alfa-romero giulia alfa-romero stelvio  \
# car_ID                            1                   2
# symboling                         3                   3
# doornumber                      two                 two
# carbody                 convertible         convertible
# enginelocation                front               front
# wheelbase                      88.6                88.6
# carlength                     168.8               168.8
# carwidth                       64.1                64.1
# carheight                      48.8                48.8
# curbweight                     2548                2548
# cylindernumber                 four                four
# enginesize                      130                 130
# boreratio                      3.47                3.47
# stroke                         2.68                2.68
# compressionratio                9.0                 9.0
# horsepower                      111                 111
# peakrpm                        5000                5000
# citympg                          21                  21
# highwaympg                       27                  27
# price                       13495.0             16500.0
#
# carname          alfa-romero Quadrifoglio audi 100 ls audi 100ls audi fox  \
# car_ID                                  3           4          5        6
# symboling                               1           2          2        2
# doornumber                            two        four       four      two
# carbody                         hatchback       sedan      sedan    sedan
# enginelocation                      front       front      front    front
# wheelbase                            94.5        99.8       99.4     99.8
# carlength                           171.2       176.6      176.6    177.3
# carwidth                             65.5        66.2       66.4     66.3
# carheight                            52.4        54.3       54.3     53.1
# curbweight                           2823        2337       2824     2507
# cylindernumber                        six        four       five     five
# enginesize                            152         109        136      136
# boreratio                            2.68        3.19       3.19     3.19
# stroke                               3.47         3.4        3.4      3.4
# compressionratio                      9.0        10.0        8.0      8.5
# horsepower                            154         102        115      110
# peakrpm                              5000        5500       5500     5500
# citympg                                19          24         18       19
# highwaympg                             26          30         22       25
# price                             16500.0     13950.0    17450.0  15250.0
#
# carname          audi 5000 audi 4000 audi 5000s (diesel) bmw 320i  ...  \
# car_ID                   8         9                  10       11  ...
# symboling                1         1                   0        2  ...
# doornumber            four      four                 two      two  ...
# carbody              wagon     sedan           hatchback    sedan  ...
# enginelocation       front     front               front    front  ...
# wheelbase            105.8     105.8                99.5    101.2  ...
# carlength            192.7     192.7               178.2    176.8  ...
# carwidth              71.4      71.4                67.9     64.8  ...
# carheight             55.7      55.9                52.0     54.3  ...
# curbweight            2954      3086                3053     2395  ...
# cylindernumber        five      five                five     four  ...
# enginesize             136       131                 131      108  ...
# boreratio             3.19      3.13                3.13      3.5  ...
# stroke                 3.4       3.4                 3.4      2.8  ...
# compressionratio       8.5       8.3                 7.0      8.8  ...
# horsepower             110       140                 160      101  ...
# peakrpm               5500      5500                5500     5800  ...
# citympg                 19        17                  16       23  ...
# highwaympg              25        20                  22       29  ...
# price              18920.0   23875.0           17859.167  16430.0  ...
#
# carname           vw rabbit volkswagen rabbit volkswagen rabbit custom  \
# car_ID                  191               192                      193
# symboling                 3                 0                        0
# doornumber              two              four                     four
# carbody           hatchback             sedan                    sedan
# enginelocation        front             front                    front
# wheelbase              94.5             100.4                    100.4
# carlength             165.7             180.2                    180.2
# carwidth               64.0              66.9                     66.9
# carheight              51.4              55.1                     55.1
# curbweight             2221              2661                     2579
# cylindernumber         four              five                     four
# enginesize              109               136                       97
# boreratio              3.19              3.19                     3.01
# stroke                  3.4               3.4                      3.4
# compressionratio        8.5               8.5                     23.0
# horsepower               90               110                       68
# peakrpm                5500              5500                     4500
# citympg                  24                19                       33
# highwaympg               29                24                       38
# price                9980.0           13295.0                  13845.0
#
# carname          volvo 145e (sw) volvo 144ea volvo 244dl volvo 245  \
# car_ID                       195         196         197       198
# symboling                     -2          -1          -2        -1
# doornumber                  four        four        four      four
# carbody                    sedan       wagon       sedan     wagon
# enginelocation             front       front       front     front
# wheelbase                  104.3       104.3       104.3     104.3
# carlength                  188.8       188.8       188.8     188.8
# carwidth                    67.2        67.2        67.2      67.2
# carheight                   56.2        57.5        56.2      57.5
# curbweight                  2912        3034        2935      3042
# cylindernumber              four        four        four      four
# enginesize                   141         141         141       141
# boreratio                   3.78        3.78        3.78      3.78
# stroke                      3.15        3.15        3.15      3.15
# compressionratio             9.5         9.5         9.5       9.5
# horsepower                   114         114         114       114
# peakrpm                     5400        5400        5400      5400
# citympg                       23          23          24        24
# highwaympg                    28          28          28        28
# price                    12940.0     13415.0     15985.0   16515.0
#
# carname          volvo 264gl volvo diesel volvo 246
# car_ID                   199          200       204
# symboling                 -2           -1        -1
# doornumber              four         four      four
# carbody                sedan        wagon     sedan
# enginelocation         front        front     front
# wheelbase              104.3        104.3     109.1
# carlength              188.8        188.8     188.8
# carwidth                67.2         67.2      68.9
# carheight               56.2         57.5      55.5
# curbweight              3045         3157      3217
# cylindernumber          four         four       six
# enginesize               130          130       145
# boreratio               3.62         3.62      3.01
# stroke                  3.15         3.15       3.4
# compressionratio         7.5          7.5      23.0
# horsepower               162          162       106
# peakrpm                 5100         5100      4800
# citympg                   17           17        26
# highwaympg                22           22        27
# price                18420.0      18950.0   22470.0
#
# [20 rows x 147 columns]

# %% [markdown]
# We have used the `.transpose()` method to swap the axes of the dataframe here. It is easy to see that the two axes of dataframes are basically collections of series. A pair of series intersect at a single entry in the dataframe.

# %% [markdown]
# We will study further operations on dataframes in detail in a later session.

# %% [markdown]
# We have seen some of the important attributes and methods that help in quickly familiarizing ourselves with datasets. Learners are expected to explore this further on their own. You can study more about Pandas dataframes [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html).

# %% [markdown]
# ### Quiz
# Print the top four observations in the `df_cars` dataframe.

# %%
df_cars.head(4)
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0

# %% [markdown]
# ### Quiz
# Print the bottom six observations in the `df_cars` dataframe.

# %%
df_cars.tail(6)
# Out:
#               car_ID  symboling doornumber carbody enginelocation  wheelbase  \
# carname
# volvo 144ea      196         -1       four   wagon          front      104.3
# volvo 244dl      197         -2       four   sedan          front      104.3
# volvo 245        198         -1       four   wagon          front      104.3
# volvo 264gl      199         -2       four   sedan          front      104.3
# volvo diesel     200         -1       four   wagon          front      104.3
# volvo 246        204         -1       four   sedan          front      109.1
#
#               carlength  carwidth  carheight  curbweight cylindernumber  \
# carname
# volvo 144ea       188.8      67.2       57.5        3034           four
# volvo 244dl       188.8      67.2       56.2        2935           four
# volvo 245         188.8      67.2       57.5        3042           four
# volvo 264gl       188.8      67.2       56.2        3045           four
# volvo diesel      188.8      67.2       57.5        3157           four
# volvo 246         188.8      68.9       55.5        3217            six
#
#               enginesize  boreratio  stroke  compressionratio  horsepower  \
# carname
# volvo 144ea          141       3.78    3.15               9.5         114
# volvo 244dl          141       3.78    3.15               9.5         114
# volvo 245            141       3.78    3.15               9.5         114
# volvo 264gl          130       3.62    3.15               7.5         162
# volvo diesel         130       3.62    3.15               7.5         162
# volvo 246            145       3.01    3.40              23.0         106
#
#               peakrpm  citympg  highwaympg    price
# carname
# volvo 144ea      5400       23          28  13415.0
# volvo 244dl      5400       24          28  15985.0
# volvo 245        5400       24          28  16515.0
# volvo 264gl      5100       17          22  18420.0
# volvo diesel     5100       17          22  18950.0
# volvo 246        4800       26          27  22470.0

# %% [markdown]
# # Accessing data from dataframes
# In this section, we will study various access methods to access data from dataframes. We will focus more on the fundamentals in this session and briefly look at some other important methods. Note that you will work with these operations and methods throughout your data science learning journey and beyond.

# %% [markdown]
# ### Example
# Direct access

# %%
df_cars
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
# ...                          ...        ...        ...          ...
# volvo 244dl                  197         -2       four        sedan
# volvo 245                    198         -1       four        wagon
# volvo 264gl                  199         -2       four        sedan
# volvo diesel                 200         -1       four        wagon
# volvo 246                    204         -1       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [147 rows x 20 columns]

# %%
df_cars['price']
# Out:
# carname
# alfa-romero giulia          13495.0
# alfa-romero stelvio         16500.0
# alfa-romero Quadrifoglio    16500.0
# audi 100 ls                 13950.0
# audi 100ls                  17450.0
#                              ...
# volvo 244dl                 15985.0
# volvo 245                   16515.0
# volvo 264gl                 18420.0
# volvo diesel                18950.0
# volvo 246                   22470.0
# Name: price, Length: 147, dtype: float64

# %% [markdown]
# Note that the resulting object is also a Pandas indexable object, like a series or a dataframe. So, you can continue to use relevant accessing methods.

# %%
df_cars[['doornumber','carbody']] # to display multiple columns
# Out:
#                          doornumber      carbody
# carname
# alfa-romero giulia              two  convertible
# alfa-romero stelvio             two  convertible
# alfa-romero Quadrifoglio        two    hatchback
# audi 100 ls                    four        sedan
# audi 100ls                     four        sedan
# ...                             ...          ...
# volvo 244dl                    four        sedan
# volvo 245                      four        wagon
# volvo 264gl                    four        sedan
# volvo diesel                   four        wagon
# volvo 246                      four        sedan
#
# [147 rows x 2 columns]

# %%
df_cars['price']['audi 100 ls']
# Out:
# 13950.0

# %% [markdown]
# You can also access the pricing column as shown below, but this method is applicable only when the name of the column is a single string.

# %%
df_cars.price
# Out:
# carname
# alfa-romero giulia          13495.0
# alfa-romero stelvio         16500.0
# alfa-romero Quadrifoglio    16500.0
# audi 100 ls                 13950.0
# audi 100ls                  17450.0
#                              ...
# volvo 244dl                 15985.0
# volvo 245                   16515.0
# volvo 264gl                 18420.0
# volvo diesel                18950.0
# volvo 246                   22470.0
# Name: price, Length: 147, dtype: float64

# %%
df_cars[['carbody', 'price']]
# Out:
#                               carbody    price
# carname
# alfa-romero giulia        convertible  13495.0
# alfa-romero stelvio       convertible  16500.0
# alfa-romero Quadrifoglio    hatchback  16500.0
# audi 100 ls                     sedan  13950.0
# audi 100ls                      sedan  17450.0
# ...                               ...      ...
# volvo 244dl                     sedan  15985.0
# volvo 245                       wagon  16515.0
# volvo 264gl                     sedan  18420.0
# volvo diesel                    wagon  18950.0
# volvo 246                       sedan  22470.0
#
# [147 rows x 2 columns]

# %% [markdown]
# Direct access methods are not as robust as we would want them to be, but this is where the `.loc[]` and the `.iloc[]` methods help.

# %% [markdown]
# ### Example
# Accessing using the `.loc[]` method

# %%
df_cars.loc[['audi 100 ls', 'volvo diesel'], ['carbody', 'price']]
# Out:
#              carbody    price
# carname
# audi 100 ls    sedan  13950.0
# volvo diesel   wagon  18950.0

# %% [markdown]
# Notice the format of the indexer. It is rows first, and then columns.

# %%
df_cars.loc[['audi 100 ls', 'volvo diesel'], ['boreratio', 'price']]
# Out:
#               boreratio    price
# carname
# audi 100 ls        3.19  13950.0
# volvo diesel       3.62  18950.0

# %%
df_cars.loc['alfa-romero stelvio':'audi 100ls', ['carbody', 'price']]
# Out:
#                               carbody    price
# carname
# alfa-romero stelvio       convertible  16500.0
# alfa-romero Quadrifoglio    hatchback  16500.0
# audi 100 ls                     sedan  13950.0
# audi 100ls                      sedan  17450.0

# %%
df_cars.loc['alfa-romero stelvio':'audi 100ls', 'wheelbase':'curbweight']
# Out:
#                           wheelbase  carlength  carwidth  carheight  \
# carname
# alfa-romero stelvio            88.6      168.8      64.1       48.8
# alfa-romero Quadrifoglio       94.5      171.2      65.5       52.4
# audi 100 ls                    99.8      176.6      66.2       54.3
# audi 100ls                     99.4      176.6      66.4       54.3
#
#                           curbweight
# carname
# alfa-romero stelvio             2548
# alfa-romero Quadrifoglio        2823
# audi 100 ls                     2337
# audi 100ls                      2824

# %%
df_cars.loc[:, 'wheelbase':'curbweight']
# Out:
#                           wheelbase  carlength  carwidth  carheight  \
# carname
# alfa-romero giulia             88.6      168.8      64.1       48.8
# alfa-romero stelvio            88.6      168.8      64.1       48.8
# alfa-romero Quadrifoglio       94.5      171.2      65.5       52.4
# audi 100 ls                    99.8      176.6      66.2       54.3
# audi 100ls                     99.4      176.6      66.4       54.3
# ...                             ...        ...       ...        ...
# volvo 244dl                   104.3      188.8      67.2       56.2
# volvo 245                     104.3      188.8      67.2       57.5
# volvo 264gl                   104.3      188.8      67.2       56.2
# volvo diesel                  104.3      188.8      67.2       57.5
# volvo 246                     109.1      188.8      68.9       55.5
#
#                           curbweight
# carname
# alfa-romero giulia              2548
# alfa-romero stelvio             2548
# alfa-romero Quadrifoglio        2823
# audi 100 ls                     2337
# audi 100ls                      2824
# ...                              ...
# volvo 244dl                     2935
# volvo 245                       3042
# volvo 264gl                     3045
# volvo diesel                    3157
# volvo 246                       3217
#
# [147 rows x 5 columns]

# %%
df_cars.loc['alfa-romero stelvio':'audi 100ls', :]
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0

# %% [markdown]
# ### Example
# Accessing using the `.iloc[]` method

# %% [markdown]
# The `.iloc[]` method follows the same format as the `.loc[]` method with two major differences. Firstly, we already know that the `.iloc[]` method excludes the stop value. Secondly, the `.loc[]` method depends on the names of the rows and columns, so shuffling the dataset will not produce different results as long as the right names are used, but the `.iloc[]` method strictly works on integer index positioning, so the results will be different if the datasets are different.

# %%
df_cars.iloc[0, 2]
# Out:
# 'two'

# %%
df_cars.iloc[[0, 3, 6], [2, 5, 10]]
# Out:
#                    doornumber  wheelbase cylindernumber
# carname
# alfa-romero giulia        two       88.6           four
# audi 100 ls              four       99.8           four
# audi 5000                four      105.8           five

# %%
df_cars.iloc[3:110, [2, 5, 10]]
# Out:
#             doornumber  wheelbase cylindernumber
# carname
# audi 100 ls       four       99.8           four
# audi 100ls        four       99.4           five
# audi fox           two       99.8           five
# audi 5000         four      105.8           five
# audi 4000         four      105.8           five
# ...                ...        ...            ...
# subaru dl          two       93.7           four
# subaru brz        four       97.2           four
# subaru baja       four       97.2           four
# subaru r1         four       97.0           four
# subaru r2         four       97.0           four
#
# [107 rows x 3 columns]

# %%
df_cars.iloc[[0, 3, 6], :]
# Out:
#                     car_ID  symboling doornumber      carbody enginelocation  \
# carname
# alfa-romero giulia       1          3        two  convertible          front
# audi 100 ls              4          2       four        sedan          front
# audi 5000                8          1       four        wagon          front
#
#                     wheelbase  carlength  carwidth  carheight  curbweight  \
# carname
# alfa-romero giulia       88.6      168.8      64.1       48.8        2548
# audi 100 ls              99.8      176.6      66.2       54.3        2337
# audi 5000               105.8      192.7      71.4       55.7        2954
#
#                    cylindernumber  enginesize  boreratio  stroke  \
# carname
# alfa-romero giulia           four         130       3.47    2.68
# audi 100 ls                  four         109       3.19    3.40
# audi 5000                    five         136       3.19    3.40
#
#                     compressionratio  horsepower  peakrpm  citympg  \
# carname
# alfa-romero giulia               9.0         111     5000       21
# audi 100 ls                     10.0         102     5500       24
# audi 5000                        8.5         110     5500       19
#
#                     highwaympg    price
# carname
# alfa-romero giulia          27  13495.0
# audi 100 ls                 30  13950.0
# audi 5000                   25  18920.0

# %% [markdown]
# ### Example
# Boolean indexing

# %%
df_cars['enginesize'] > 120
# Out:
# carname
# alfa-romero giulia           True
# alfa-romero stelvio          True
# alfa-romero Quadrifoglio     True
# audi 100 ls                 False
# audi 100ls                   True
#                             ...
# volvo 244dl                  True
# volvo 245                    True
# volvo 264gl                  True
# volvo diesel                 True
# volvo 246                    True
# Name: enginesize, Length: 147, dtype: bool

# %%
df_cars[df_cars['enginesize'] > 120]
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100ls                     5          2       four        sedan
# audi fox                       6          2        two        sedan
# ...                          ...        ...        ...          ...
# volvo 244dl                  197         -2       four        sedan
# volvo 245                    198         -1       four        wagon
# volvo 264gl                  199         -2       four        sedan
# volvo diesel                 200         -1       four        wagon
# volvo 246                    204         -1       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100ls                        front       99.4      176.6      66.4
# audi fox                          front       99.8      177.3      66.3
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100ls                     54.3        2824           five         136
# audi fox                       53.1        2507           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100ls                     3.19    3.40               8.0         115
# audi fox                       3.19    3.40               8.5         110
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100ls                   5500       18          22  17450.0
# audi fox                     5500       19          25  15250.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [63 rows x 20 columns]

# %%
df_cars[df_cars['doornumber']=='two']
# Out:
#                               car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia                 1          3        two  convertible
# alfa-romero stelvio                2          3        two  convertible
# alfa-romero Quadrifoglio           3          1        two    hatchback
# audi fox                           6          2        two        sedan
# audi 5000s (diesel)               10          0        two    hatchback
# ...                              ...        ...        ...          ...
# toyota cressida                  173          2        two  convertible
# vokswagen rabbit                 183          2        two        sedan
# volkswagen 1131 deluxe sedan     184          2        two        sedan
# vw dasher                        190          3        two  convertible
# vw rabbit                        191          3        two    hatchback
#
#                              enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                    front       88.6      168.8      64.1
# alfa-romero stelvio                   front       88.6      168.8      64.1
# alfa-romero Quadrifoglio              front       94.5      171.2      65.5
# audi fox                              front       99.8      177.3      66.3
# audi 5000s (diesel)                   front       99.5      178.2      67.9
# ...                                     ...        ...        ...       ...
# toyota cressida                       front       98.4      176.2      65.6
# vokswagen rabbit                      front       97.3      171.7      65.5
# volkswagen 1131 deluxe sedan          front       97.3      171.7      65.5
# vw dasher                             front       94.5      159.3      64.2
# vw rabbit                             front       94.5      165.7      64.0
#
#                               carheight  curbweight cylindernumber  \
# carname
# alfa-romero giulia                 48.8        2548           four
# alfa-romero stelvio                48.8        2548           four
# alfa-romero Quadrifoglio           52.4        2823            six
# audi fox                           53.1        2507           five
# audi 5000s (diesel)                52.0        3053           five
# ...                                 ...         ...            ...
# toyota cressida                    53.0        2975           four
# vokswagen rabbit                   55.7        2261           four
# volkswagen 1131 deluxe sedan       55.7        2209           four
# vw dasher                          55.6        2254           four
# vw rabbit                          51.4        2221           four
#
#                               enginesize  boreratio  stroke  compressionratio  \
# carname
# alfa-romero giulia                   130       3.47    2.68               9.0
# alfa-romero stelvio                  130       3.47    2.68               9.0
# alfa-romero Quadrifoglio             152       2.68    3.47               9.0
# audi fox                             136       3.19    3.40               8.5
# audi 5000s (diesel)                  131       3.13    3.40               7.0
# ...                                  ...        ...     ...               ...
# toyota cressida                      146       3.62    3.50               9.3
# vokswagen rabbit                      97       3.01    3.40              23.0
# volkswagen 1131 deluxe sedan         109       3.19    3.40               9.0
# vw dasher                            109       3.19    3.40               8.5
# vw rabbit                            109       3.19    3.40               8.5
#
#                               horsepower  peakrpm  citympg  highwaympg  \
# carname
# alfa-romero giulia                   111     5000       21          27
# alfa-romero stelvio                  111     5000       21          27
# alfa-romero Quadrifoglio             154     5000       19          26
# audi fox                             110     5500       19          25
# audi 5000s (diesel)                  160     5500       16          22
# ...                                  ...      ...      ...         ...
# toyota cressida                      116     4800       24          30
# vokswagen rabbit                      52     4800       37          46
# volkswagen 1131 deluxe sedan          85     5250       27          34
# vw dasher                             90     5500       24          29
# vw rabbit                             90     5500       24          29
#
#                                   price
# carname
# alfa-romero giulia            13495.000
# alfa-romero stelvio           16500.000
# alfa-romero Quadrifoglio      16500.000
# audi fox                      15250.000
# audi 5000s (diesel)           17859.167
# ...                                 ...
# toyota cressida               17669.000
# vokswagen rabbit               7775.000
# volkswagen 1131 deluxe sedan   7975.000
# vw dasher                     11595.000
# vw rabbit                      9980.000
#
# [72 rows x 20 columns]

# %%
(df_cars['enginesize'] > 120) & (df_cars['carbody'] == 'sedan')
# Out:
# carname
# alfa-romero giulia          False
# alfa-romero stelvio         False
# alfa-romero Quadrifoglio    False
# audi 100 ls                 False
# audi 100ls                   True
#                             ...
# volvo 244dl                  True
# volvo 245                   False
# volvo 264gl                  True
# volvo diesel                False
# volvo 246                    True
# Length: 147, dtype: bool

# %%
df_cars[(df_cars['enginesize'] > 120) & (df_cars['carbody'] == 'sedan')]
# Out:
#                           car_ID  symboling doornumber carbody enginelocation  \
# carname
# audi 100ls                     5          2       four   sedan          front
# audi fox                       6          2        two   sedan          front
# audi 4000                      9          1       four   sedan          front
# bmw x1                        13          0        two   sedan          front
# bmw x3                        14          0       four   sedan          front
# bmw z4                        15          1       four   sedan          front
# bmw x4                        16          0       four   sedan          front
# bmw x5                        17          0        two   sedan          front
# jaguar xj                     48          0       four   sedan          front
# jaguar xf                     49          0       four   sedan          front
# jaguar xk                     50          0        two   sedan          front
# mazda glc custom l            61          0       four   sedan          front
# buick electra 225 custom      68         -1       four   sedan          front
# buick skyhawk                 71         -1       four   sedan          front
# buick opel isuzu deluxe       72         -1       four   sedan          front
# buick century special         74          0       four   sedan          front
# mitsubishi montero            86          1       four   sedan          front
# mitsubishi pajero             87          1       four   sedan          front
# nissan dayz                  102          0       four   sedan          front
# nissan otti                  104          0       four   sedan          front
# peugeot 304                  109          0       four   sedan          front
# peugeot 604sl                113          0       four   sedan          front
# saab 99le                    134          2       four   sedan          front
# saab 99gle                   136          2       four   sedan          front
# volkswagen rabbit            192          0       four   sedan          front
# volvo 145e (sw)              195         -2       four   sedan          front
# volvo 244dl                  197         -2       four   sedan          front
# volvo 264gl                  199         -2       four   sedan          front
# volvo 246                    204         -1       four   sedan          front
#
#                           wheelbase  carlength  carwidth  carheight  \
# carname
# audi 100ls                     99.4      176.6      66.4       54.3
# audi fox                       99.8      177.3      66.3       53.1
# audi 4000                     105.8      192.7      71.4       55.9
# bmw x1                        101.2      176.8      64.8       54.3
# bmw x3                        101.2      176.8      64.8       54.3
# bmw z4                        103.5      189.0      66.9       55.7
# bmw x4                        103.5      189.0      66.9       55.7
# bmw x5                        103.5      193.8      67.9       53.7
# jaguar xj                     113.0      199.6      69.6       52.8
# jaguar xf                     113.0      199.6      69.6       52.8
# jaguar xk                     102.0      191.7      70.6       47.8
# mazda glc custom l             98.8      177.8      66.5       55.5
# buick electra 225 custom      110.0      190.9      70.3       56.5
# buick skyhawk                 115.6      202.6      71.7       56.3
# buick opel isuzu deluxe       115.6      202.6      71.7       56.5
# buick century special         120.9      208.1      71.7       56.7
# mitsubishi montero             96.3      172.4      65.4       51.6
# mitsubishi pajero              96.3      172.4      65.4       51.6
# nissan dayz                   100.4      181.7      66.5       55.1
# nissan otti                   100.4      184.6      66.5       55.1
# peugeot 304                   107.9      186.7      68.4       56.7
# peugeot 604sl                 107.9      186.7      68.4       56.7
# saab 99le                      99.1      186.6      66.5       56.1
# saab 99gle                     99.1      186.6      66.5       56.1
# volkswagen rabbit             100.4      180.2      66.9       55.1
# volvo 145e (sw)               104.3      188.8      67.2       56.2
# volvo 244dl                   104.3      188.8      67.2       56.2
# volvo 264gl                   104.3      188.8      67.2       56.2
# volvo 246                     109.1      188.8      68.9       55.5
#
#                           curbweight cylindernumber  enginesize  boreratio  \
# carname
# audi 100ls                      2824           five         136       3.19
# audi fox                        2507           five         136       3.19
# audi 4000                       3086           five         131       3.13
# bmw x1                          2710            six         164       3.31
# bmw x3                          2765            six         164       3.31
# bmw z4                          3055            six         164       3.31
# bmw x4                          3230            six         209       3.62
# bmw x5                          3380            six         209       3.62
# jaguar xj                       4066            six         258       3.63
# jaguar xf                       4066            six         258       3.63
# jaguar xk                       3950         twelve         326       3.54
# mazda glc custom l              2410           four         122       3.39
# buick electra 225 custom        3515           five         183       3.58
# buick skyhawk                   3770           five         183       3.58
# buick opel isuzu deluxe         3740          eight         234       3.46
# buick century special           3900          eight         308       3.80
# mitsubishi montero              2365           four         122       3.35
# mitsubishi pajero               2405           four         122       3.35
# nissan dayz                     3095            six         181       3.43
# nissan otti                     3060            six         181       3.43
# peugeot 304                     3197           four         152       3.70
# peugeot 604sl                   3252           four         152       3.70
# saab 99le                       2695           four         121       3.54
# saab 99gle                      2758           four         121       3.54
# volkswagen rabbit               2661           five         136       3.19
# volvo 145e (sw)                 2912           four         141       3.78
# volvo 244dl                     2935           four         141       3.78
# volvo 264gl                     3045           four         130       3.62
# volvo 246                       3217            six         145       3.01
#
#                           stroke  compressionratio  horsepower  peakrpm  \
# carname
# audi 100ls                  3.40               8.0         115     5500
# audi fox                    3.40               8.5         110     5500
# audi 4000                   3.40               8.3         140     5500
# bmw x1                      3.19               9.0         121     4250
# bmw x3                      3.19               9.0         121     4250
# bmw z4                      3.19               9.0         121     4250
# bmw x4                      3.39               8.0         182     5400
# bmw x5                      3.39               8.0         182     5400
# jaguar xj                   4.17               8.1         176     4750
# jaguar xf                   4.17               8.1         176     4750
# jaguar xk                   2.76              11.5         262     5000
# mazda glc custom l          3.39               8.6          84     4800
# buick electra 225 custom    3.64              21.5         123     4350
# buick skyhawk               3.64              21.5         123     4350
# buick opel isuzu deluxe     3.10               8.3         155     4750
# buick century special       3.35               8.0         184     4500
# mitsubishi montero          3.46               8.5          88     5000
# mitsubishi pajero           3.46               8.5          88     5000
# nissan dayz                 3.27               9.0         152     5200
# nissan otti                 3.27               9.0         152     5200
# peugeot 304                 3.52              21.0          95     4150
# peugeot 604sl               3.52              21.0          95     4150
# saab 99le                   3.07               9.3         110     5250
# saab 99gle                  3.07               9.3         110     5250
# volkswagen rabbit           3.40               8.5         110     5500
# volvo 145e (sw)             3.15               9.5         114     5400
# volvo 244dl                 3.15               9.5         114     5400
# volvo 264gl                 3.15               7.5         162     5100
# volvo 246                   3.40              23.0         106     4800
#
#                           citympg  highwaympg    price
# carname
# audi 100ls                     18          22  17450.0
# audi fox                       19          25  15250.0
# audi 4000                      17          20  23875.0
# bmw x1                         21          28  20970.0
# bmw x3                         21          28  21105.0
# bmw z4                         20          25  24565.0
# bmw x4                         16          22  30760.0
# bmw x5                         16          22  41315.0
# jaguar xj                      15          19  32250.0
# jaguar xf                      15          19  35550.0
# jaguar xk                      13          17  36000.0
# mazda glc custom l             26          32   8495.0
# buick electra 225 custom       22          25  25552.0
# buick skyhawk                  22          25  31600.0
# buick opel isuzu deluxe        16          18  34184.0
# buick century special          14          16  40960.0
# mitsubishi montero             25          32   6989.0
# mitsubishi pajero              25          32   8189.0
# nissan dayz                    17          22  13499.0
# nissan otti                    19          25  13499.0
# peugeot 304                    28          33  13200.0
# peugeot 604sl                  28          33  16900.0
# saab 99le                      21          28  12170.0
# saab 99gle                     21          28  15510.0
# volkswagen rabbit              19          24  13295.0
# volvo 145e (sw)                23          28  12940.0
# volvo 244dl                    24          28  15985.0
# volvo 264gl                    17          22  18420.0
# volvo 246                      26          27  22470.0

# %%
enginesize_condition = df_cars['enginesize'] > 120
carbody_condition = df_cars['carbody'] == 'sedan'
price_condition = df_cars['price'] < 12500

df_cars[enginesize_condition & carbody_condition & price_condition]
# Out:
#                     car_ID  symboling doornumber carbody enginelocation  \
# carname
# mazda glc custom l      61          0       four   sedan          front
# mitsubishi montero      86          1       four   sedan          front
# mitsubishi pajero       87          1       four   sedan          front
# saab 99le              134          2       four   sedan          front
#
#                     wheelbase  carlength  carwidth  carheight  curbweight  \
# carname
# mazda glc custom l       98.8      177.8      66.5       55.5        2410
# mitsubishi montero       96.3      172.4      65.4       51.6        2365
# mitsubishi pajero        96.3      172.4      65.4       51.6        2405
# saab 99le                99.1      186.6      66.5       56.1        2695
#
#                    cylindernumber  enginesize  boreratio  stroke  \
# carname
# mazda glc custom l           four         122       3.39    3.39
# mitsubishi montero           four         122       3.35    3.46
# mitsubishi pajero            four         122       3.35    3.46
# saab 99le                    four         121       3.54    3.07
#
#                     compressionratio  horsepower  peakrpm  citympg  \
# carname
# mazda glc custom l               8.6          84     4800       26
# mitsubishi montero               8.5          88     5000       25
# mitsubishi pajero                8.5          88     5000       25
# saab 99le                        9.3         110     5250       21
#
#                     highwaympg    price
# carname
# mazda glc custom l          32   8495.0
# mitsubishi montero          32   6989.0
# mitsubishi pajero           32   8189.0
# saab 99le                   28  12170.0

# %%
enginesize_condition = df_cars['enginesize'] > 120
carbody_condition = df_cars['carbody'] == 'sedan'
price_condition = df_cars['price'] < 12500
carheight_condition = df_cars['carheight'] > 50
df_cars[(enginesize_condition & carbody_condition & price_condition) | carheight_condition]
# Out:
#                           car_ID  symboling doornumber    carbody  \
# carname
# alfa-romero Quadrifoglio       3          1        two  hatchback
# audi 100 ls                    4          2       four      sedan
# audi 100ls                     5          2       four      sedan
# audi fox                       6          2        two      sedan
# audi 5000                      8          1       four      wagon
# ...                          ...        ...        ...        ...
# volvo 244dl                  197         -2       four      sedan
# volvo 245                    198         -1       four      wagon
# volvo 264gl                  199         -2       four      sedan
# volvo diesel                 200         -1       four      wagon
# volvo 246                    204         -1       four      sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
# audi fox                          front       99.8      177.3      66.3
# audi 5000                         front      105.8      192.7      71.4
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
# audi fox                       53.1        2507           five         136
# audi 5000                      55.7        2954           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
# audi fox                       3.19    3.40               8.5         110
# audi 5000                      3.19    3.40               8.5         110
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0
# audi fox                     5500       19          25  15250.0
# audi 5000                    5500       19          25  18920.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [137 rows x 20 columns]

# %%
subset_cars = df_cars[(enginesize_condition & carbody_condition & price_condition) | carheight_condition]
subset_cars
# Out:
#                           car_ID  symboling doornumber    carbody  \
# carname
# alfa-romero Quadrifoglio       3          1        two  hatchback
# audi 100 ls                    4          2       four      sedan
# audi 100ls                     5          2       four      sedan
# audi fox                       6          2        two      sedan
# audi 5000                      8          1       four      wagon
# ...                          ...        ...        ...        ...
# volvo 244dl                  197         -2       four      sedan
# volvo 245                    198         -1       four      wagon
# volvo 264gl                  199         -2       four      sedan
# volvo diesel                 200         -1       four      wagon
# volvo 246                    204         -1       four      sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
# audi fox                          front       99.8      177.3      66.3
# audi 5000                         front      105.8      192.7      71.4
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
# audi fox                       53.1        2507           five         136
# audi 5000                      55.7        2954           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
# audi fox                       3.19    3.40               8.5         110
# audi 5000                      3.19    3.40               8.5         110
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0
# audi fox                     5500       19          25  15250.0
# audi 5000                    5500       19          25  18920.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [137 rows x 20 columns]

# %%
subset_cars.index
# Out:
# Index(['alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls', 'audi fox',
#        'audi 5000', 'audi 4000', 'audi 5000s (diesel)', 'bmw 320i', 'bmw x1',
#        'bmw x3',
#        ...
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'],
#       dtype='object', name='carname', length=137)

# %%
subset_cars.loc[:, 'wheelbase':'curbweight']
# Out:
#                           wheelbase  carlength  carwidth  carheight  \
# carname
# alfa-romero Quadrifoglio       94.5      171.2      65.5       52.4
# audi 100 ls                    99.8      176.6      66.2       54.3
# audi 100ls                     99.4      176.6      66.4       54.3
# audi fox                       99.8      177.3      66.3       53.1
# audi 5000                     105.8      192.7      71.4       55.7
# ...                             ...        ...       ...        ...
# volvo 244dl                   104.3      188.8      67.2       56.2
# volvo 245                     104.3      188.8      67.2       57.5
# volvo 264gl                   104.3      188.8      67.2       56.2
# volvo diesel                  104.3      188.8      67.2       57.5
# volvo 246                     109.1      188.8      68.9       55.5
#
#                           curbweight
# carname
# alfa-romero Quadrifoglio        2823
# audi 100 ls                     2337
# audi 100ls                      2824
# audi fox                        2507
# audi 5000                       2954
# ...                              ...
# volvo 244dl                     2935
# volvo 245                       3042
# volvo 264gl                     3045
# volvo diesel                    3157
# volvo 246                       3217
#
# [137 rows x 5 columns]

# %%
subset_cars.loc['volvo 244dl':'volvo diesel', 'wheelbase':'curbweight']
# Out:
#               wheelbase  carlength  carwidth  carheight  curbweight
# carname
# volvo 244dl       104.3      188.8      67.2       56.2        2935
# volvo 245         104.3      188.8      67.2       57.5        3042
# volvo 264gl       104.3      188.8      67.2       56.2        3045
# volvo diesel      104.3      188.8      67.2       57.5        3157

# %% [markdown]
# The `.isin()` method is quite helpful in executing conditional access from dataframes.

# %%
df_cars['carbody'].isin(['wagon', 'sedan'])
# Out:
# carname
# alfa-romero giulia          False
# alfa-romero stelvio         False
# alfa-romero Quadrifoglio    False
# audi 100 ls                  True
# audi 100ls                   True
#                             ...
# volvo 244dl                  True
# volvo 245                    True
# volvo 264gl                  True
# volvo diesel                 True
# volvo 246                    True
# Name: carbody, Length: 147, dtype: bool

# %%
df_cars[df_cars['carbody'].isin(['wagon', 'sedan'])]
# Out:
#               car_ID  symboling doornumber carbody enginelocation  wheelbase  \
# carname
# audi 100 ls        4          2       four   sedan          front       99.8
# audi 100ls         5          2       four   sedan          front       99.4
# audi fox           6          2        two   sedan          front       99.8
# audi 5000          8          1       four   wagon          front      105.8
# audi 4000          9          1       four   sedan          front      105.8
# ...              ...        ...        ...     ...            ...        ...
# volvo 244dl      197         -2       four   sedan          front      104.3
# volvo 245        198         -1       four   wagon          front      104.3
# volvo 264gl      199         -2       four   sedan          front      104.3
# volvo diesel     200         -1       four   wagon          front      104.3
# volvo 246        204         -1       four   sedan          front      109.1
#
#               carlength  carwidth  carheight  curbweight cylindernumber  \
# carname
# audi 100 ls       176.6      66.2       54.3        2337           four
# audi 100ls        176.6      66.4       54.3        2824           five
# audi fox          177.3      66.3       53.1        2507           five
# audi 5000         192.7      71.4       55.7        2954           five
# audi 4000         192.7      71.4       55.9        3086           five
# ...                 ...       ...        ...         ...            ...
# volvo 244dl       188.8      67.2       56.2        2935           four
# volvo 245         188.8      67.2       57.5        3042           four
# volvo 264gl       188.8      67.2       56.2        3045           four
# volvo diesel      188.8      67.2       57.5        3157           four
# volvo 246         188.8      68.9       55.5        3217            six
#
#               enginesize  boreratio  stroke  compressionratio  horsepower  \
# carname
# audi 100 ls          109       3.19    3.40              10.0         102
# audi 100ls           136       3.19    3.40               8.0         115
# audi fox             136       3.19    3.40               8.5         110
# audi 5000            136       3.19    3.40               8.5         110
# audi 4000            131       3.13    3.40               8.3         140
# ...                  ...        ...     ...               ...         ...
# volvo 244dl          141       3.78    3.15               9.5         114
# volvo 245            141       3.78    3.15               9.5         114
# volvo 264gl          130       3.62    3.15               7.5         162
# volvo diesel         130       3.62    3.15               7.5         162
# volvo 246            145       3.01    3.40              23.0         106
#
#               peakrpm  citympg  highwaympg    price
# carname
# audi 100 ls      5500       24          30  13950.0
# audi 100ls       5500       18          22  17450.0
# audi fox         5500       19          25  15250.0
# audi 5000        5500       19          25  18920.0
# audi 4000        5500       17          20  23875.0
# ...               ...      ...         ...      ...
# volvo 244dl      5400       24          28  15985.0
# volvo 245        5400       24          28  16515.0
# volvo 264gl      5100       17          22  18420.0
# volvo diesel     5100       17          22  18950.0
# volvo 246        4800       26          27  22470.0
#
# [88 rows x 20 columns]

# %%
df_cars[~df_cars['carbody'].isin(['wagon', 'sedan'])]
# Out:
#                                  car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia                    1          3        two  convertible
# alfa-romero stelvio                   2          3        two  convertible
# alfa-romero Quadrifoglio              3          1        two    hatchback
# audi 5000s (diesel)                  10          0        two    hatchback
# chevrolet impala                     19          2        two    hatchback
# chevrolet monte carlo                20          1        two    hatchback
# dodge rampage                        22          1        two    hatchback
# dodge challenger se                  23          1        two    hatchback
# dodge d200                           24          1        two    hatchback
# dodge monaco (sw)                    25          1       four    hatchback
# dodge coronet custom (sw)            30          3        two    hatchback
# honda civic                          31          2        two    hatchback
# honda civic cvcc                     32          2        two    hatchback
# honda accord cvcc                    34          1        two    hatchback
# honda accord                         38          0        two    hatchback
# honda civic 1300                     39          0        two    hatchback
# maxda rx3                            51          1        two    hatchback
# maxda glc deluxe                     52          1        two    hatchback
# mazda rx2 coupe                      53          1        two    hatchback
# mazda 626                            56          3        two    hatchback
# mazda glc                            57          3        two    hatchback
# mazda rx-7 gs                        58          3        two    hatchback
# mazda glc 4                          59          3        two    hatchback
# mazda glc custom                     62          1        two    hatchback
# buick century                        70          0        two      hardtop
# buick skylark                        73          3        two  convertible
# buick regal sport coupe (turbo)      75          1        two      hardtop
# mercury cougar                       76          1        two    hatchback
# mitsubishi mirage                    77          2        two    hatchback
# mitsubishi lancer                    78          2        two    hatchback
# mitsubishi outlander                 79          2        two    hatchback
# mitsubishi g4                        80          1        two    hatchback
# mitsubishi mirage g4                 81          3        two    hatchback
# nissan juke                          96          1        two    hatchback
# nissan clipper                       99          2        two      hardtop
# nissan teana                        105          3        two    hatchback
# nissan kicks                        106          3        two    hatchback
# plymouth fury iii                   119          1        two    hatchback
# plymouth cricket                    120          1        two    hatchback
# plymouth duster                     125          3        two    hatchback
# porsche macan                       126          3        two    hatchback
# porcshce panamera                   127          3        two      hardtop
# porsche cayenne                     128          3        two      hardtop
# porsche boxter                      129          3        two  convertible
# renault 5 gtl                       132          2        two    hatchback
# saab 99e                            133          3        two    hatchback
# subaru                              139          2        two    hatchback
# subaru dl                           140          2        two    hatchback
# toyota corona mark ii               151          1        two    hatchback
# toyota corona                       152          1        two    hatchback
# toyota corolla 1200                 153          1       four    hatchback
# toyota corolla                      160          0       four    hatchback
# toyota corolla tercel               167          1        two    hatchback
# toyota corona liftback              168          2        two      hardtop
# toyota starlet                      170          2        two    hatchback
# toyota tercel                       171          2        two      hardtop
# toyota cressida                     173          2        two  convertible
# vw dasher                           190          3        two  convertible
# vw rabbit                           191          3        two    hatchback
#
#                                 enginelocation  wheelbase  carlength  \
# carname
# alfa-romero giulia                       front       88.6      168.8
# alfa-romero stelvio                      front       88.6      168.8
# alfa-romero Quadrifoglio                 front       94.5      171.2
# audi 5000s (diesel)                      front       99.5      178.2
# chevrolet impala                         front       88.4      141.1
# chevrolet monte carlo                    front       94.5      155.9
# dodge rampage                            front       93.7      157.3
# dodge challenger se                      front       93.7      157.3
# dodge d200                               front       93.7      157.3
# dodge monaco (sw)                        front       93.7      157.3
# dodge coronet custom (sw)                front       95.9      173.2
# honda civic                              front       86.6      144.6
# honda civic cvcc                         front       86.6      144.6
# honda accord cvcc                        front       93.7      150.0
# honda accord                             front       96.5      167.5
# honda civic 1300                         front       96.5      167.5
# maxda rx3                                front       93.1      159.1
# maxda glc deluxe                         front       93.1      159.1
# mazda rx2 coupe                          front       93.1      159.1
# mazda 626                                front       95.3      169.0
# mazda glc                                front       95.3      169.0
# mazda rx-7 gs                            front       95.3      169.0
# mazda glc 4                              front       95.3      169.0
# mazda glc custom                         front       98.8      177.8
# buick century                            front      106.7      187.5
# buick skylark                            front       96.6      180.3
# buick regal sport coupe (turbo)          front      112.0      199.2
# mercury cougar                           front      102.7      178.4
# mitsubishi mirage                        front       93.7      157.3
# mitsubishi lancer                        front       93.7      157.3
# mitsubishi outlander                     front       93.7      157.3
# mitsubishi g4                            front       93.0      157.3
# mitsubishi mirage g4                     front       96.3      173.0
# nissan juke                              front       94.5      165.6
# nissan clipper                           front       95.1      162.4
# nissan teana                             front       91.3      170.7
# nissan kicks                             front       91.3      170.7
# plymouth fury iii                        front       93.7      157.3
# plymouth cricket                         front       93.7      157.3
# plymouth duster                          front       95.9      173.2
# porsche macan                            front       94.5      168.9
# porcshce panamera                         rear       89.5      168.9
# porsche cayenne                           rear       89.5      168.9
# porsche boxter                            rear       89.5      168.9
# renault 5 gtl                            front       96.1      176.8
# saab 99e                                 front       99.1      186.6
# subaru                                   front       93.7      156.9
# subaru dl                                front       93.7      157.9
# toyota corona mark ii                    front       95.7      158.7
# toyota corona                            front       95.7      158.7
# toyota corolla 1200                      front       95.7      158.7
# toyota corolla                           front       95.7      166.3
# toyota corolla tercel                    front       94.5      168.7
# toyota corona liftback                   front       98.4      176.2
# toyota starlet                           front       98.4      176.2
# toyota tercel                            front       98.4      176.2
# toyota cressida                          front       98.4      176.2
# vw dasher                                front       94.5      159.3
# vw rabbit                                front       94.5      165.7
#
#                                  carwidth  carheight  curbweight  \
# carname
# alfa-romero giulia                   64.1       48.8        2548
# alfa-romero stelvio                  64.1       48.8        2548
# alfa-romero Quadrifoglio             65.5       52.4        2823
# audi 5000s (diesel)                  67.9       52.0        3053
# chevrolet impala                     60.3       53.2        1488
# chevrolet monte carlo                63.6       52.0        1874
# dodge rampage                        63.8       50.8        1876
# dodge challenger se                  63.8       50.8        1876
# dodge d200                           63.8       50.8        2128
# dodge monaco (sw)                    63.8       50.6        1967
# dodge coronet custom (sw)            66.3       50.2        2811
# honda civic                          63.9       50.8        1713
# honda civic cvcc                     63.9       50.8        1819
# honda accord cvcc                    64.0       52.6        1940
# honda accord                         65.2       53.3        2236
# honda civic 1300                     65.2       53.3        2289
# maxda rx3                            64.2       54.1        1890
# maxda glc deluxe                     64.2       54.1        1900
# mazda rx2 coupe                      64.2       54.1        1905
# mazda 626                            65.7       49.6        2380
# mazda glc                            65.7       49.6        2380
# mazda rx-7 gs                        65.7       49.6        2385
# mazda glc 4                          65.7       49.6        2500
# mazda glc custom                     66.5       53.7        2385
# buick century                        70.3       54.9        3495
# buick skylark                        70.5       50.8        3685
# buick regal sport coupe (turbo)      72.0       55.4        3715
# mercury cougar                       68.0       54.8        2910
# mitsubishi mirage                    64.4       50.8        1918
# mitsubishi lancer                    64.4       50.8        1944
# mitsubishi outlander                 64.4       50.8        2004
# mitsubishi g4                        63.8       50.8        2145
# mitsubishi mirage g4                 65.4       49.4        2370
# nissan juke                          63.8       53.3        2028
# nissan clipper                       63.8       53.3        2008
# nissan teana                         67.9       49.7        3071
# nissan kicks                         67.9       49.7        3139
# plymouth fury iii                    63.8       50.8        1918
# plymouth cricket                     63.8       50.8        2128
# plymouth duster                      66.3       50.2        2818
# porsche macan                        68.3       50.2        2778
# porcshce panamera                    65.0       51.6        2756
# porsche cayenne                      65.0       51.6        2756
# porsche boxter                       65.0       51.6        2800
# renault 5 gtl                        66.6       50.5        2460
# saab 99e                             66.5       56.1        2658
# subaru                               63.4       53.7        2050
# subaru dl                            63.6       53.7        2120
# toyota corona mark ii                63.6       54.5        1985
# toyota corona                        63.6       54.5        2040
# toyota corolla 1200                  63.6       54.5        2015
# toyota corolla                       64.4       52.8        2275
# toyota corolla tercel                64.0       52.6        2300
# toyota corona liftback               65.6       52.0        2540
# toyota starlet                       65.6       52.0        2551
# toyota tercel                        65.6       52.0        2679
# toyota cressida                      65.6       53.0        2975
# vw dasher                            64.2       55.6        2254
# vw rabbit                            64.0       51.4        2221
#
#                                 cylindernumber  enginesize  boreratio  stroke  \
# carname
# alfa-romero giulia                        four         130       3.47   2.680
# alfa-romero stelvio                       four         130       3.47   2.680
# alfa-romero Quadrifoglio                   six         152       2.68   3.470
# audi 5000s (diesel)                       five         131       3.13   3.400
# chevrolet impala                         three          61       2.91   3.030
# chevrolet monte carlo                     four          90       3.03   3.110
# dodge rampage                             four          90       2.97   3.230
# dodge challenger se                       four          90       2.97   3.230
# dodge d200                                four          98       3.03   3.390
# dodge monaco (sw)                         four          90       2.97   3.230
# dodge coronet custom (sw)                 four         156       3.60   3.900
# honda civic                               four          92       2.91   3.410
# honda civic cvcc                          four          92       2.91   3.410
# honda accord cvcc                         four          92       2.91   3.410
# honda accord                              four         110       3.15   3.580
# honda civic 1300                          four         110       3.15   3.580
# maxda rx3                                 four          91       3.03   3.150
# maxda glc deluxe                          four          91       3.03   3.150
# mazda rx2 coupe                           four          91       3.03   3.150
# mazda 626                                  two          70       3.33   3.255
# mazda glc                                  two          70       3.33   3.255
# mazda rx-7 gs                              two          70       3.33   3.255
# mazda glc 4                                two          80       3.33   3.255
# mazda glc custom                          four         122       3.39   3.390
# buick century                             five         183       3.58   3.640
# buick skylark                            eight         234       3.46   3.100
# buick regal sport coupe (turbo)          eight         304       3.80   3.350
# mercury cougar                            four         140       3.78   3.120
# mitsubishi mirage                         four          92       2.97   3.230
# mitsubishi lancer                         four          92       2.97   3.230
# mitsubishi outlander                      four          92       2.97   3.230
# mitsubishi g4                             four          98       3.03   3.390
# mitsubishi mirage g4                      four         110       3.17   3.460
# nissan juke                               four          97       3.15   3.290
# nissan clipper                            four          97       3.15   3.290
# nissan teana                               six         181       3.43   3.270
# nissan kicks                               six         181       3.43   3.270
# plymouth fury iii                         four          90       2.97   3.230
# plymouth cricket                          four          98       3.03   3.390
# plymouth duster                           four         156       3.59   3.860
# porsche macan                             four         151       3.94   3.110
# porcshce panamera                          six         194       3.74   2.900
# porsche cayenne                            six         194       3.74   2.900
# porsche boxter                             six         194       3.74   2.900
# renault 5 gtl                             four         132       3.46   3.900
# saab 99e                                  four         121       3.54   3.070
# subaru                                    four          97       3.62   2.360
# subaru dl                                 four         108       3.62   2.640
# toyota corona mark ii                     four          92       3.05   3.030
# toyota corona                             four          92       3.05   3.030
# toyota corolla 1200                       four          92       3.05   3.030
# toyota corolla                            four         110       3.27   3.350
# toyota corolla tercel                     four          98       3.24   3.080
# toyota corona liftback                    four         146       3.62   3.500
# toyota starlet                            four         146       3.62   3.500
# toyota tercel                             four         146       3.62   3.500
# toyota cressida                           four         146       3.62   3.500
# vw dasher                                 four         109       3.19   3.400
# vw rabbit                                 four         109       3.19   3.400
#
#                                  compressionratio  horsepower  peakrpm  \
# carname
# alfa-romero giulia                           9.00         111     5000
# alfa-romero stelvio                          9.00         111     5000
# alfa-romero Quadrifoglio                     9.00         154     5000
# audi 5000s (diesel)                          7.00         160     5500
# chevrolet impala                             9.50          48     5100
# chevrolet monte carlo                        9.60          70     5400
# dodge rampage                                9.41          68     5500
# dodge challenger se                          9.40          68     5500
# dodge d200                                   7.60         102     5500
# dodge monaco (sw)                            9.40          68     5500
# dodge coronet custom (sw)                    7.00         145     5000
# honda civic                                  9.60          58     4800
# honda civic cvcc                             9.20          76     6000
# honda accord cvcc                            9.20          76     6000
# honda accord                                 9.00          86     5800
# honda civic 1300                             9.00          86     5800
# maxda rx3                                    9.00          68     5000
# maxda glc deluxe                             9.00          68     5000
# mazda rx2 coupe                              9.00          68     5000
# mazda 626                                    9.40         101     6000
# mazda glc                                    9.40         101     6000
# mazda rx-7 gs                                9.40         101     6000
# mazda glc 4                                  9.40         135     6000
# mazda glc custom                             8.60          84     4800
# buick century                               21.50         123     4350
# buick skylark                                8.30         155     4750
# buick regal sport coupe (turbo)              8.00         184     4500
# mercury cougar                               8.00         175     5000
# mitsubishi mirage                            9.40          68     5500
# mitsubishi lancer                            9.40          68     5500
# mitsubishi outlander                         9.40          68     5500
# mitsubishi g4                                7.60         102     5500
# mitsubishi mirage g4                         7.50         116     5500
# nissan juke                                  9.40          69     5200
# nissan clipper                               9.40          69     5200
# nissan teana                                 9.00         160     5200
# nissan kicks                                 7.80         200     5200
# plymouth fury iii                            9.40          68     5500
# plymouth cricket                             7.60         102     5500
# plymouth duster                              7.00         145     5000
# porsche macan                                9.50         143     5500
# porcshce panamera                            9.50         207     5900
# porsche cayenne                              9.50         207     5900
# porsche boxter                               9.50         207     5900
# renault 5 gtl                                8.70          90     5100
# saab 99e                                     9.31         110     5250
# subaru                                       9.00          69     4900
# subaru dl                                    8.70          73     4400
# toyota corona mark ii                        9.00          62     4800
# toyota corona                                9.00          62     4800
# toyota corolla 1200                          9.00          62     4800
# toyota corolla                              22.50          56     4500
# toyota corolla tercel                        9.40         112     6600
# toyota corona liftback                       9.30         116     4800
# toyota starlet                               9.30         116     4800
# toyota tercel                                9.30         116     4800
# toyota cressida                              9.30         116     4800
# vw dasher                                    8.50          90     5500
# vw rabbit                                    8.50          90     5500
#
#                                  citympg  highwaympg      price
# carname
# alfa-romero giulia                    21          27  13495.000
# alfa-romero stelvio                   21          27  16500.000
# alfa-romero Quadrifoglio              19          26  16500.000
# audi 5000s (diesel)                   16          22  17859.167
# chevrolet impala                      47          53   5151.000
# chevrolet monte carlo                 38          43   6295.000
# dodge rampage                         37          41   5572.000
# dodge challenger se                   31          38   6377.000
# dodge d200                            24          30   7957.000
# dodge monaco (sw)                     31          38   6229.000
# dodge coronet custom (sw)             19          24  12964.000
# honda civic                           49          54   6479.000
# honda civic cvcc                      31          38   6855.000
# honda accord cvcc                     30          34   6529.000
# honda accord                          27          33   7895.000
# honda civic 1300                      27          33   9095.000
# maxda rx3                             30          31   5195.000
# maxda glc deluxe                      31          38   6095.000
# mazda rx2 coupe                       31          38   6795.000
# mazda 626                             17          23  10945.000
# mazda glc                             17          23  11845.000
# mazda rx-7 gs                         17          23  13645.000
# mazda glc 4                           16          23  15645.000
# mazda glc custom                      26          32  10595.000
# buick century                         22          25  28176.000
# buick skylark                         16          18  35056.000
# buick regal sport coupe (turbo)       14          16  45400.000
# mercury cougar                        19          24  16503.000
# mitsubishi mirage                     37          41   5389.000
# mitsubishi lancer                     31          38   6189.000
# mitsubishi outlander                  31          38   6669.000
# mitsubishi g4                         24          30   7689.000
# mitsubishi mirage g4                  23          30   9959.000
# nissan juke                           31          37   7799.000
# nissan clipper                        31          37   8249.000
# nissan teana                          19          25  17199.000
# nissan kicks                          17          23  19699.000
# plymouth fury iii                     37          41   5572.000
# plymouth cricket                      24          30   7957.000
# plymouth duster                       19          24  12764.000
# porsche macan                         19          27  22018.000
# porcshce panamera                     17          25  32528.000
# porsche cayenne                       17          25  34028.000
# porsche boxter                        17          25  37028.000
# renault 5 gtl                         23          31   9895.000
# saab 99e                              21          28  11850.000
# subaru                                31          36   5118.000
# subaru dl                             26          31   7053.000
# toyota corona mark ii                 35          39   5348.000
# toyota corona                         31          38   6338.000
# toyota corolla 1200                   31          38   6488.000
# toyota corolla                        38          47   7788.000
# toyota corolla tercel                 26          29   9538.000
# toyota corona liftback                24          30   8449.000
# toyota starlet                        24          30   9989.000
# toyota tercel                         24          30  11199.000
# toyota cressida                       24          30  17669.000
# vw dasher                             24          29  11595.000
# vw rabbit                             24          29   9980.000

# %% [markdown]
# ### Example
#
# Accessing columns with specific data types

# %%
int_columns = df_cars.select_dtypes(include = 'int')
int_columns
# Out:
#                           car_ID  symboling  curbweight  enginesize  \
# carname
# alfa-romero giulia             1          3        2548         130
# alfa-romero stelvio            2          3        2548         130
# alfa-romero Quadrifoglio       3          1        2823         152
# audi 100 ls                    4          2        2337         109
# audi 100ls                     5          2        2824         136
# ...                          ...        ...         ...         ...
# volvo 244dl                  197         -2        2935         141
# volvo 245                    198         -1        3042         141
# volvo 264gl                  199         -2        3045         130
# volvo diesel                 200         -1        3157         130
# volvo 246                    204         -1        3217         145
#
#                           horsepower  peakrpm  citympg  highwaympg
# carname
# alfa-romero giulia               111     5000       21          27
# alfa-romero stelvio              111     5000       21          27
# alfa-romero Quadrifoglio         154     5000       19          26
# audi 100 ls                      102     5500       24          30
# audi 100ls                       115     5500       18          22
# ...                              ...      ...      ...         ...
# volvo 244dl                      114     5400       24          28
# volvo 245                        114     5400       24          28
# volvo 264gl                      162     5100       17          22
# volvo diesel                     162     5100       17          22
# volvo 246                        106     4800       26          27
#
# [147 rows x 8 columns]

# %%
float_columns = df_cars.select_dtypes(include = 'float')
float_columns
# Out:
#                           wheelbase  carlength  carwidth  carheight  \
# carname
# alfa-romero giulia             88.6      168.8      64.1       48.8
# alfa-romero stelvio            88.6      168.8      64.1       48.8
# alfa-romero Quadrifoglio       94.5      171.2      65.5       52.4
# audi 100 ls                    99.8      176.6      66.2       54.3
# audi 100ls                     99.4      176.6      66.4       54.3
# ...                             ...        ...       ...        ...
# volvo 244dl                   104.3      188.8      67.2       56.2
# volvo 245                     104.3      188.8      67.2       57.5
# volvo 264gl                   104.3      188.8      67.2       56.2
# volvo diesel                  104.3      188.8      67.2       57.5
# volvo 246                     109.1      188.8      68.9       55.5
#
#                           boreratio  stroke  compressionratio    price
# carname
# alfa-romero giulia             3.47    2.68               9.0  13495.0
# alfa-romero stelvio            3.47    2.68               9.0  16500.0
# alfa-romero Quadrifoglio       2.68    3.47               9.0  16500.0
# audi 100 ls                    3.19    3.40              10.0  13950.0
# audi 100ls                     3.19    3.40               8.0  17450.0
# ...                             ...     ...               ...      ...
# volvo 244dl                    3.78    3.15               9.5  15985.0
# volvo 245                      3.78    3.15               9.5  16515.0
# volvo 264gl                    3.62    3.15               7.5  18420.0
# volvo diesel                   3.62    3.15               7.5  18950.0
# volvo 246                      3.01    3.40              23.0  22470.0
#
# [147 rows x 8 columns]

# %%
df_cars
# Out:
#                           car_ID  symboling doornumber      carbody  \
# carname
# alfa-romero giulia             1          3        two  convertible
# alfa-romero stelvio            2          3        two  convertible
# alfa-romero Quadrifoglio       3          1        two    hatchback
# audi 100 ls                    4          2       four        sedan
# audi 100ls                     5          2       four        sedan
# ...                          ...        ...        ...          ...
# volvo 244dl                  197         -2       four        sedan
# volvo 245                    198         -1       four        wagon
# volvo 264gl                  199         -2       four        sedan
# volvo diesel                 200         -1       four        wagon
# volvo 246                    204         -1       four        sedan
#
#                          enginelocation  wheelbase  carlength  carwidth  \
# carname
# alfa-romero giulia                front       88.6      168.8      64.1
# alfa-romero stelvio               front       88.6      168.8      64.1
# alfa-romero Quadrifoglio          front       94.5      171.2      65.5
# audi 100 ls                       front       99.8      176.6      66.2
# audi 100ls                        front       99.4      176.6      66.4
# ...                                 ...        ...        ...       ...
# volvo 244dl                       front      104.3      188.8      67.2
# volvo 245                         front      104.3      188.8      67.2
# volvo 264gl                       front      104.3      188.8      67.2
# volvo diesel                      front      104.3      188.8      67.2
# volvo 246                         front      109.1      188.8      68.9
#
#                           carheight  curbweight cylindernumber  enginesize  \
# carname
# alfa-romero giulia             48.8        2548           four         130
# alfa-romero stelvio            48.8        2548           four         130
# alfa-romero Quadrifoglio       52.4        2823            six         152
# audi 100 ls                    54.3        2337           four         109
# audi 100ls                     54.3        2824           five         136
# ...                             ...         ...            ...         ...
# volvo 244dl                    56.2        2935           four         141
# volvo 245                      57.5        3042           four         141
# volvo 264gl                    56.2        3045           four         130
# volvo diesel                   57.5        3157           four         130
# volvo 246                      55.5        3217            six         145
#
#                           boreratio  stroke  compressionratio  horsepower  \
# carname
# alfa-romero giulia             3.47    2.68               9.0         111
# alfa-romero stelvio            3.47    2.68               9.0         111
# alfa-romero Quadrifoglio       2.68    3.47               9.0         154
# audi 100 ls                    3.19    3.40              10.0         102
# audi 100ls                     3.19    3.40               8.0         115
# ...                             ...     ...               ...         ...
# volvo 244dl                    3.78    3.15               9.5         114
# volvo 245                      3.78    3.15               9.5         114
# volvo 264gl                    3.62    3.15               7.5         162
# volvo diesel                   3.62    3.15               7.5         162
# volvo 246                      3.01    3.40              23.0         106
#
#                           peakrpm  citympg  highwaympg    price
# carname
# alfa-romero giulia           5000       21          27  13495.0
# alfa-romero stelvio          5000       21          27  16500.0
# alfa-romero Quadrifoglio     5000       19          26  16500.0
# audi 100 ls                  5500       24          30  13950.0
# audi 100ls                   5500       18          22  17450.0
# ...                           ...      ...         ...      ...
# volvo 244dl                  5400       24          28  15985.0
# volvo 245                    5400       24          28  16515.0
# volvo 264gl                  5100       17          22  18420.0
# volvo diesel                 5100       17          22  18950.0
# volvo 246                    4800       26          27  22470.0
#
# [147 rows x 20 columns]

# %% [markdown]
# ### Quiz
# Print the `'price'`, `'enginelocation'`, `'citympg'`, and `'cylindernumber'` details of the cars `'nissan teana'`, `'toyota corolla tercel'`, and `'volkswagen type 3'` from the `df_cars` dataframe.

# %%
df_cars.loc[['nissan teana', 'toyota corolla tercel', 'volkswagen type 3'],
            ['price', 'enginelocation', 'citympg', 'cylindernumber']]
# Out:
#                          price enginelocation  citympg cylindernumber
# carname
# nissan teana           17199.0          front       19            six
# toyota corolla tercel   9538.0          front       26           four
# volkswagen type 3       8195.0          front       27           four

# %% [markdown]
# ### Quiz
# Print the names of the cars that have a `'carbody'` type of `'sedan'`, a `'highwaympg'` value greater than 45, and whose prices are not more than 22000 dollars.

# %%
carbody_condition = df_cars['carbody'] == 'sedan'
hmpg_condition = df_cars['highwaympg'] > 45
price_condition = df_cars['price'] <= 22000
print(list(df_cars[(carbody_condition) & (hmpg_condition) & (price_condition)].index))
# Out:
# ['nissan gt-r', 'vokswagen rabbit', 'volkswagen model 111']

# %% [markdown]
# In this session, we studied Pandas series and dataframes, two of the most popular and important data structures for handling real-world data, especially tabular data. We looked into their basic attributes and also learned how to query them by using various accessing methods.
